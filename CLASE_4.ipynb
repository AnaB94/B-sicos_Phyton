# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaB94/B-sicos_Phyton/blob/main/CLASE_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#index_col sirve para poner a una columna como indice
#nrow filas para analizar

df=pd.read_excel(io="/content/titanic.xlsx",index_col=None,nrows=100,usecols=[1,2,4,5]
                 )

df_filtrado=df.dropna() # quita los na
df_mayor=df_filtrado=df[df['Age']>18]
df_mayor.head()
# Out:
#    Survived  Pclass     Sex   Age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0

# %%
df_mayor.tail()
# Out:
#     Survived  Pclass     Sex   Age
# 94         0       3    male  59.0
# 96         0       1    male  71.0
# 97         1       1    male  23.0
# 98         1       2  female  34.0
# 99         0       2    male  34.0

# %%
df_mayor.query("Age<5").count
# Out:
# <bound method DataFrame.count of Empty DataFrame
# Columns: [Survived, Pclass, Sex, Age]
# Index: []>

# %%
df_femele=df_mayor.query("Sex=='female'")
df_femele
# Out:
#     Survived  Pclass     Sex   Age
# 1          1       1  female  38.0
# 2          1       3  female  26.0
# 3          1       1  female  35.0
# 8          1       3  female  27.0
# 11         1       1  female  58.0
# 15         1       2  female  55.0
# 18         0       3  female  31.0
# 25         1       3  female  38.0
# 40         0       3  female  40.0
# 41         0       2  female  27.0
# 44         1       3  female  19.0
# 52         1       1  female  49.0
# 53         1       2  female  29.0
# 56         1       2  female  21.0
# 61         1       1  female  38.0
# 66         1       2  female  29.0
# 79         1       3  female  30.0
# 85         1       3  female  33.0
# 88         1       1  female  23.0
# 98         1       2  female  34.0
